# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Мария, привет! Рад с тобой познакомиться :)**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если удобнее на «вы», просто напиши, и мы сменим стиль общения.
#
# Я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Просьба не менять их местами и не удалять, чтобы наша работа над проектом была максимально продуктивной. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их исправления проект не будет принят. Я оцениваю не только код, но и его интерпретацию, а также соответствие техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации, которые стоит учесть. Это не критично, но поможет сделать работу лучше. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению отсутствуют заголовок, краткое описание задачи, ход и цель исследования. Хорошо структурированное вступление делает проект более профессиональным, понятным и ценным для читателя и заказчика.
#
# Вот краткий пример на основе проекта: Исследовательский анализ данных.
#
# ![%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg](attachment:%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавила заголовок, краткое описание задачи, ход и цель исследования
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# **Заголовок:** Исследование сервиса аренды самокатов GoFast.

# %% [markdown]
# **Описание проекта:** В наши дни существует множество альтернатив передвижения, но все чаще популярность приобретают самокаты, ведь это удобный и экологичный вид транспорта. С помощью данных сервиса GoFast, предлагающего аренду самокатов, который включает в себя данные о пользователях, их поездках и подписках, мы стремимся выявить факторы, вляющие на использование сервиса. Понимание поведения пользователей и их предпочтений позволит не только улучшить качество предоставляемых услуг, но и разработать эффективные стратегии для привлечения новых клиентов и удержания существующих. В ходе анализа мы также проверим несколько гипотез, которые могут помочь в выявлении возможностей для роста и развития бизнеса.

# %% [markdown]
# **Цель исследования:** Провести анализ данных о пользователях и их поездках с целью выявления ключевых факторов, влияющих на использование сервиса.

# %% [markdown]
# **Ход исследования:**
#
# - Подготовка данных: загрузка и изучение общей информации из представленного датасета.
# - Предобработка данных: проверка на наличие пропущенных значений и дубликатов в датафреймах, приведение данных к корректному виду.
# - Расширение набора данных: объединение датафреймов, добавление новых столбцов, таких как, помесячная выручка и тд.
# - Исследовательский анализ данных: проверка гипотез, изучение основных параметров.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# ## Шаг 1. Загрузка данных

# %%
#считываем файлы
users_go = pd.read_csv('/datasets/users_go.csv')
rides_go = pd.read_csv('/datasets/rides_go.csv')
subscription_fee = pd.read_csv('/datasets/subscriptions_go.csv')

# %%
#считываем файлы
try:
    users_go = pd.read_csv('users_go.csv')
except:
    users_go = pd.read_csv('/datasets/users_go.csv')

# %%
try:
    rides_go = pd.read_csv('rides_go.csv')
except:
    rides_go = pd.read_csv('/datasets/rides_go.csv')

# %%
try:
    subscription_fee = pd.read_csv('subscriptions_go.csv')
except:
    subscription_fee = pd.read_csv('/datasets/subscriptions_go.csv')

# %% [markdown]
# **Изучаем информацию для users_go**

# %%
users_go.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
users_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# **Изучаем информацию для rides_go**

# %%
rides_go.head()
# Out:
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28

# %%
rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %% [markdown]
# **Изучаем информацию для subscription_fee**

# %%
subscription_fee.head()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199

# %%
subscription_fee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# К сожалению здесь код упал с ошибкой. Для локальной работы рекомендую использовать `try-except` блок, где, например в try ты пропишешь путь для локальной работы, а в except путь для работы на платформе ЯП. Поправь, пожалуйста и я буду ждать твою работу на повторное ревью.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Прописала блок try-except для считывания файлов.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Мария, я прошу простить, проверял сразу два проекта по статистике и этот комментарий предназначался не тебе, у тебя не было ошибки с падением кода :(( Но, для информации все-равно полезно 😉
#
#
# Вот тут можно почитать подробнее о конструкции по [ссылка](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)
# </div>

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
#2.1 Привели столбец date к типу даты pandas.
rides_go['date'] = pd.to_datetime(rides_go['date'])
rides_go.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 564.8 KB

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# На предыдущем шаге, при вызове метода info() можно заметить что в датафрейме rides_go столбец date был типа object, исправили на тип данных datetime64, после чего повторно вызвали метод, чтобы убедиться, что тип данных изменился

# %%
# 2.2 Создали новый столбец с номером месяца на основе столбца date.
rides_go['month'] = rides_go['date'].dt.month
rides_go.head()
# Out:
#    user_id     distance   duration       date  month
# 0        1  4409.919140  25.599769 2021-01-01      1
# 1        1  2617.592153  15.816871 2021-01-18      1
# 2        1   754.159807   6.232113 2021-04-20      4
# 3        1  2694.783254  18.511000 2021-08-11      8
# 4        1  4028.687306  26.265803 2021-08-28      8

# %% [markdown]
# **2.3 Проверим наличие пропущенных значений и дубликатов в датафреймах**

# %%
users_go.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
rides_go.isna().sum()
# Out:
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64

# %%
subscription_fee.isna().sum()
# Out:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Для того, чтобы проверить наличие пропусков в датафреймах вызываем метод isna().sum(). В данном случае ни в одном датафрейме пропусков не наблюдается.

# %% [markdown]
# **2.4 Проверяем наличие явных дубликатов в датафреймах**

# %%
users_go.duplicated().sum()
# Out:
# 31

# %%
users_go = users_go.drop_duplicates()
users_go.duplicated().sum()
# Out:
# 0

# %%
rides_go.duplicated().sum()
# Out:
# 0

# %%
subscription_fee.duplicated().sum()
# Out:
# 0

# %% [markdown]
# На этом этапе мы проверили наличие явных дубликатов. Дубликаты оказались в датафрейме users_go, избавились от них с помощью метода drop_duplicates(), а затем проверили сработал ли он. В остальных датафреймах явные дубликаты не обнаружены.

# %% [markdown]
# На данном шаге мы выполнили ***предобработку данных:***
#
# - Привели столбец с датами к типу datetime
# - Создали новый столбец с номером месяца
# - Проверили наличие пропущенных значений и дубликатов, обработали их

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
#
# * Отсутствует проверка явных дубликатов, а это основа предобработки данных.
#
#
# * К сожалению отсутствует промежуточный вывод о проделанной работе в разделе. Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавила проверку на явные дубликаты, убрала из их users_go. Написала промежуточный вывод о проделанной работе в разделе.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %%
# 3.1 частота встречаемости городов
grouped_by_city = users_go['city'].value_counts()
grouped_by_city
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=grouped_by_city.index, y=grouped_by_city.values, palette='viridis')
plt.title('Частота встречаемости городов')
plt.xlabel('Города')
plt.ylabel('Количество поездок')
# Out:
# Text(0, 0.5, 'Количество поездок')

# %% [markdown]
# Видим, что наиболее встречаемые города это - Пятигорск, Екатиринбург и Ростов-на-Дону. Наименее встречаемый город - Москва.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Не могу не отметить отличную визуализацию. Здорово, что график оформлен правильно.
# </div>

# %% [markdown]
# **3.2 Соотношение пользователей с подпиской и без подписки**

# %%
grouped_by_subscription_fee = users_go['subscription_type'].value_counts()
grouped_by_subscription_fee
# Out:
# free     835
# ultra    699
# Name: subscription_type, dtype: int64

# %%
grouped_by_subscription_fee.plot.pie(y='Значение', labels=grouped_by_subscription_fee.index, autopct='%1.1f%%', startangle=90)
plt.title('Соотношение пользователей с подпиской и без подписки')
plt.axis('equal')
plt.xlabel('Соотношение')
plt.ylabel('Вид подписки')
plt.show()

# %% [markdown]
# По данной диаграмме видно, что пользователей без подписки больше.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Супер, именно доля  корректно дает ответ на поставленный вопрос.
# </div>

# %% [markdown]
# **3.3 Возраст пользователей**

# %%
users_go['age'].describe()
# Out:
# count    1534.000000
# mean       24.903520
# std         4.572367
# min        12.000000
# 25%        22.000000
# 50%        25.000000
# 75%        28.000000
# max        43.000000
# Name: age, dtype: float64

# %%
sns.boxplot(x=users_go["age"], color='lightblue')
plt.title('Возраст пользователей')
plt.xlabel('Частота')
plt.ylabel('Возраст')
# Out:
# Text(0, 0.5, 'Возраст')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Не хватает подписи осей. Прошу тебя пройтись по всем графикам и убедиться в их корректном оформлении.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Подписала оси.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# По данной визуализации видно, что средний возраст близок к медиане и составляет примерно 25 лет. Максимальный возраст - 43, минимальный - 12 лет. По графику видно, что есть 3 выброса, которые больше максимального значения и 1 выброс, который меньше минимального значения.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что используешь describe() для расчета описательных статистик.
# </div>

# %% [markdown]
# **3.4 Расстояние, которое пользователь преодолел за одну поездку**

# %%
rides_go['distance'].describe()
# Out:
# count    18068.000000
# mean      3070.659976
# std       1116.831209
# min          0.855683
# 25%       2543.226360
# 50%       3133.609994
# 75%       3776.222735
# max       7211.007745
# Name: distance, dtype: float64

# %%
sns.boxplot(x=rides_go["distance"], palette='Set2')
plt.title('Расстояние за одну поездку')
plt.xlabel('Частота')
plt.ylabel('Расстояние')
# Out:
# Text(0, 0.5, 'Расстояние')

# %% [markdown]
# По графику и таблице видим, что медиана незначительно отличается от среденего значения, что может указывать на нераномерное распределение значений, либо на наличие выбросов, на графике их достаточно много. Максимальная дистанция составляет примерно 7211, минимальная близится к 1.

# %% [markdown]
# **3.5 Продолжительность поездок**

# %%
rides_go['duration'].describe()
# Out:
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64

# %%
sns.boxplot(x=rides_go["duration"], color='salmon')
plt.title('Продолжительность поездок')
plt.xlabel('Частота')
plt.ylabel('Продолжительность')
# Out:
# Text(0, 0.5, 'Продолжительность')

# %% [markdown]
# По графику и таблице можно заметить, что среднее значение и медиана очень близки, что может говорить об узком диапозоне значений и симметричном распределении. Наличие выбросов наблюдается преимущественно за максимальным значением, есть 1 выброс меньше минимального значения. Максимальная продолжительность поездки составляет примерно 41, минимальная - 0.5.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично, двигаемся дальше.
# </div>

# %% [markdown]
# ## Шаг 4. Объединение данных

# %%
users_go.shape
# Out:
# (1534, 5)

# %%
rides_go.shape
# Out:
# (18068, 5)

# %%
subscription_fee.shape
# Out:
# (2, 4)

# %%
#4.1 Объединяем данные о пользователях, поездках и подписках в один датафрейм. 
common_data = pd.merge(users_go, rides_go, on='user_id', how='left')
common_data = pd.merge(common_data, subscription_fee, on='subscription_type', how='left')
common_data
# Out:
#        user_id     name  age       city subscription_type     distance  \
# 0            1     Кира   22     Тюмень             ultra  4409.919140
# 1            1     Кира   22     Тюмень             ultra  2617.592153
# 2            1     Кира   22     Тюмень             ultra   754.159807
# 3            1     Кира   22     Тюмень             ultra  2694.783254
# 4            1     Кира   22     Тюмень             ultra  4028.687306
# ...        ...      ...  ...        ...               ...          ...
# 18063     1534  Альберт   25  Краснодар              free  3781.098080
# 18064     1534  Альберт   25  Краснодар              free  2840.423057
# 18065     1534  Альберт   25  Краснодар              free  3826.185507
# 18066     1534  Альберт   25  Краснодар              free  2902.308661
# 18067     1534  Альберт   25  Краснодар              free  2371.711192
#
#         duration       date  month  minute_price  start_ride_price  \
# ...

# %% [markdown]
# Мы присоединяем все датасеты к users_go, его размерность (1534, 5). Однако размерность получившегося датафрейма составляет 18068 rows × 12 columns, что говорит о наличии пользователей, которые совершили несколько поездок. Воспользуемся методом drop_duplicates(), чтобы оставить только уникальные записи.

# %%
common_data = common_data.drop_duplicates(subset='user_id')
common_data.shape
# Out:
# (1534, 12)

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Вот в этом месте мы потеряли почти весь датафрейм, над которым мы бились выше :) И соответственно получили не корректные данные при подсчете помесячной выручки. Потом раскомментируй код и прогони ядро, чтобы убедиться. Пометил красным для понимания важности.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# То есть нам вообще не нужно удалять дубликаты?
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 📝
# Дубликаты важно удалять, но нужно понимать, какие именно данные ты хочешь убрать. В нашем случае `drop_duplicates(subset='user_id')` оставляет только одну строку на каждого пользователя, а все остальные удаляет. Это приводит  к потере полезных данных, если у одного пользователя было несколько записей.
#
# Если нужно удалить только полные дубликаты строк, используй просто `drop_duplicates()`. Если есть конкретные критерии для удаления, лучше изучить данные перед удалением.
#
#
# Не забудь, пожалуйста, удалить эту строку и данные дальше будут корректны.
# </div>

# %%
# Код ревьюера
common_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 18055
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
#  5   distance           1534 non-null   float64
#  6   duration           1534 non-null   float64
#  7   date               1534 non-null   datetime64[ns]
#  8   month              1534 non-null   int64
#  9   minute_price       1534 non-null   int64
#  10  start_ride_price   1534 non-null   int64
#  11  subscription_fee   1534 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 155.8+ KB

# %%
common_data.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# distance             0
# duration             0
# date                 0
# month                0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Также проверяем наличие пропусков в получившемся датафрейме с помощью метода isna().sum(). В нашем случае пропуски отсутствуют.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Для начала следует посмотреть исходную размерность датасетов
#
# * После объединения размерность таблицы, к которой присоединяем должна совпадать с исходной.
#
# * Отсутствует проверка на пропуски в объединенном датасете.
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Проверила исходную размерность датасетов, убрала дубликаты, чтобы размерность таблицы совпадала с исходной. Проверила наличие пропусков в объединенном датасете.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично!
# </div>

# %%
#создаем датафрейм с данными о пользователях без подписки
without_subscription = common_data[common_data['subscription_type'] == 'free']
without_subscription
# Out:
#        user_id       name  age            city subscription_type     distance  \
# 6500       700      Айдар   22            Омск              free  2515.690719
# 6518       701       Иван   31    Екатеринбург              free  2676.472894
# 6538       702  Мирослава   20    Екатеринбург              free   903.861985
# 6551       703       Иван   30       Пятигорск              free  3406.580225
# 6558       704      Мирон   29  Ростов-на-Дону              free  3197.139639
# ...        ...        ...  ...             ...               ...          ...
# 17989     1530  Ростислав   29            Сочи              free   133.534786
# 18006     1531     Никита   25       Пятигорск              free   711.666072
# 18029     1532    Алексей   26          Тюмень              free  2615.477834
# 18042     1533     Степан   22       Краснодар              free  3438.600356
# 18055     1534    Альберт   25       Краснодар              free  4678.415899
#
# ...

# %%
#создаем датафрейм с данными о пользователях с подпиской
with_subscription = common_data[common_data['subscription_type'] == 'ultra']
with_subscription
# Out:
#       user_id        name  age            city subscription_type     distance  \
# 0           1        Кира   22          Тюмень             ultra  4409.919140
# 12          2   Станислав   31            Омск             ultra  3105.086678
# 23          3     Алексей   20          Москва             ultra  3061.777147
# 35          4  Константин   26  Ростов-на-Дону             ultra  2905.428908
# 49          5       Адель   28            Омск             ultra  3914.646990
# ...       ...         ...  ...             ...               ...          ...
# 6465      695       Злата   14          Тюмень             ultra  2407.886529
# 6471      696       Игорь   24          Москва             ultra  3130.261665
# 6474      697      Ясмина   24          Москва             ultra  3521.261279
# 6482      698        Егор   26       Пятигорск             ultra  2727.264117
# 6492      699      Оксана   22          Москва             ultra  3433.522627
#
# ...

# %% [markdown]
# ***Исследование расстояний для обоих категорий***

# %%
without_subscription['distance'].describe()
# Out:
# count     835.000000
# mean     3051.401201
# std      1261.438895
# min        30.586955
# 25%      2364.709623
# 50%      3078.479056
# 75%      3897.545497
# max      6601.197575
# Name: distance, dtype: float64

# %%
sns.boxplot(x=without_subscription["distance"], palette='Set2')
plt.title('Расстояние за одну поездку для пользователей без подписки')
plt.xlabel('Частота')
plt.ylabel('Расстояние')
# Out:
# Text(0, 0.5, 'Расстояние')

# %% [markdown]
# По полученным данным о расстоянии за одну поездку для пользователей без подписки можем сказать, среднее и медиана отличаются, что может говорить о большом диапозоне значений, либо о наличии выбросов. По графику видно, что выбросов много за пределами максимального значения и намного меньше за пределами минимального значения. Минимальное расстояние - 30.6, максимальное - 6601. Всего данных - 835

# %%
with_subscription['distance'].describe()
# Out:
# count     699.000000
# mean     3129.999882
# std       866.035451
# min       280.964769
# 25%      2790.771968
# 50%      3170.622286
# 75%      3630.980070
# max      5699.769662
# Name: distance, dtype: float64

# %%
sns.boxplot(x=with_subscription["distance"], palette='PuRd')
plt.title('Расстояние за одну поездку для пользователей с подпиской')
plt.xlabel('Частота')
plt.ylabel('Расстояние')
# Out:
# Text(0, 0.5, 'Расстояние')

# %% [markdown]
# По полученным данным о расстоянии за одну поездку для пользователей с подпиской можем сказать, среднее и медиана отличаются. По графику видно, что выбросов много как за пределами максимального значения, так и за пределами минимального значения. Минимальное расстояние - 281, максимальное - 5699. Всего данных - 699

# %% [markdown]
# **Вывод**

# %% [markdown]
# Сравнив оба графика и таблицы, видим, что есть различия. Так пользователи чаще всего используют самокаты без подписки. Среднее расстояние с подпиской больше, чем без подписки. Медиана с подпиской незначительно выше. Минимальное расстояние для пользователей с подпиской значительно больше, чем для пользователей без подписки. Однако максимальное значение для пользователей с подпиской значительно меньше, чем для пользователей без подписки. Это говорит о том, что пользователи без подписки чаще ездят на более далекие расстояния, чем пользователи с подпиской

# %% [markdown]
# ***Исследование расстояний для обоих категорий***

# %%
without_subscription['duration'].describe()
# Out:
# count    835.000000
# mean      17.028635
# std        6.310269
# min        0.500000
# 25%       12.476831
# 50%       17.245381
# 75%       21.101619
# max       34.260124
# Name: duration, dtype: float64

# %%
sns.boxplot(x=without_subscription["duration"], palette='Set2')
plt.title('Длительность поездки для пользователей без подписки')
plt.xlabel('Частота')
plt.ylabel('Продолжительность')
# Out:
# Text(0, 0.5, 'Продолжительность')

# %% [markdown]
# По графику и таблице о длительности поездки для пользователей без подписки видно, что средене значение и медиана очень близки, что говорит об узком диапозоне значений. Выбросов не так много, есть за пределами максимального значения. Минимальная длительность поездки - 0.5, максимальная - 35.

# %%
with_subscription['duration'].describe()
# Out:
# count    699.000000
# mean      18.729142
# std        5.864928
# min        4.513962
# 25%       14.345006
# 50%       18.291776
# 75%       22.288855
# max       39.873856
# Name: duration, dtype: float64

# %%
sns.boxplot(x=with_subscription["duration"], palette='PuRd')
plt.title('Длительность поездки для пользователей с подпиской')
plt.xlabel('Частота')
plt.ylabel('Продолжительность')
# Out:
# Text(0, 0.5, 'Продолжительность')

# %% [markdown]
# По графику и таблице о длительности поездки для пользователей с подпиской видно, что средене значение и медиана очень близки, что говорит об узком диапозоне значений. Выбросов достаточно много, наблюдаются за пределами максимального значения. Минимальная длительность поездки - 4.5, максимальная - 40.

# %% [markdown]
# **Вывод**

# %% [markdown]
# Сравнив данные для двух групп, можно заметить некие различия. Минимальная длительность поездки для пользователей без подписки меньше, чем для пользователей с подпиской. Максимальная длительность также меньше для пользователей без подписки. Среденее значение больше у пользователей с подпиской, медиана также больше у пользователей с подпиской, что говорит о том, что пользователи с подпиской брали самокат на более длительное время, чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы верны, визуализация корректная. Здорово, что есть сравнения профилей пользователей двух категорий.
# </div>

# %% [markdown]
# ## Шаг 5. Подсчёт выручки

# %%
# Код ревьюера
common_data['duration'] = np.ceil(common_data['duration'])
# Out:
# /tmp/ipykernel_182/1934056632.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   common_data['duration'] = np.ceil(common_data['duration'])

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Твой код ниже является избыточным. Я закомментировал его и немного подправил группировку ниже. Теперь мы получили совершенно верный результат. Прошу тебя изучить и задать вопросы, если есть.
# </div>

# %%
#Округляем продолжительность поездки
# common_data['rounded_duration'] = np.ceil(common_data['duration']).astype(int)
# common_data

# %%
#5.1 Создаем датафрейм с агрегированными данными 
monthly_data = common_data.groupby(['user_id', 'month']).agg(
    total_distance=('distance', 'sum'),  
    total_rides=('duration', 'count'),  
    total_duration=('duration', 'sum'),    
    start_ride_price=('start_ride_price', 'first'),  
    minute_price=('minute_price', 'first'),
    subscription_fee=('subscription_fee', 'first'),
#    rounded_duration=('rounded_duration', 'sum')  
).reset_index()
monthly_data
# Out:
#       user_id  month  total_distance  total_rides  total_duration  \
# 0           1      1     4409.919140            1            26.0
# 1           2      3     3105.086678            1            25.0
# 2           3      1     3061.777147            1            13.0
# 3           4      2     2905.428908            1            28.0
# 4           5      1     3914.646990            1            13.0
# ...       ...    ...             ...          ...             ...
# 1529     1530      1      133.534786            1             6.0
# 1530     1531      1      711.666072            1            13.0
# 1531     1532      1     2615.477834            1            15.0
# 1532     1533      1     3438.600356            1            21.0
# 1533     1534      1     4678.415899            1            16.0
#
#       start_ride_price  minute_price  subscription_fee
# 0                    0             6               199
# 1                    0             6               199
# ...

# %%
#Создаем функцию, чтобы посчитать ежемесячную выручку
def calculate_revenue(row):
    revenue = (row['start_ride_price'] * row['total_rides'] + 
               row['minute_price'] * row['total_duration'] +
               row['subscription_fee'])
    return revenue

# Применяем функцию для расчета выручки
monthly_data['revenue'] = monthly_data.apply(calculate_revenue, axis=1)
monthly_data
# Out:
#       user_id  month  total_distance  total_rides  total_duration  \
# 0           1      1     4409.919140            1            26.0
# 1           2      3     3105.086678            1            25.0
# 2           3      1     3061.777147            1            13.0
# 3           4      2     2905.428908            1            28.0
# 4           5      1     3914.646990            1            13.0
# ...       ...    ...             ...          ...             ...
# 1529     1530      1      133.534786            1             6.0
# 1530     1531      1      711.666072            1            13.0
# 1531     1532      1     2615.477834            1            15.0
# 1532     1533      1     3438.600356            1            21.0
# 1533     1534      1     4678.415899            1            16.0
#
#       start_ride_price  minute_price  subscription_fee  revenue
# 0                    0             6               199    355.0
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Мария, ты допустила несколько ошибок, которые приводят к неверному результату.
#
#
# * **Отсутствует группировка по месяцам:** ты агрегируешь данные только по user_id, но выручка считается помесячно, поэтому группировка должна быть по user_id и month.
#
#
# * **Неправильный расчёт выручки:** ты складываешь start_ride_price, minute_price * rounded_duration и subscription_fee, но стоимость старта должна умножаться на количество поездок, иначе сумма занижена.
#
#
# * **Неправильное место для расчёта выручки:** ты считаешь revenue в common_data, а потом снова агрегируешь, но это двойная работа. Выручку логичнее считать уже после группировки, чтобы избежать лишних операций.
#
#
# * **Некорректный подсчёт количества поездок:** ты используешь count() по distance, но корректнее считать через count() по duration, так как не факт, что distance всегда заполнен.
#
#
# * **Округление duration после агрегации:** ты округляешь duration уже после подсчёта общей длительности поездок, но округлять нужно до суммирования, иначе выручка считается с некорректными значениями.
#
# Исправь эти моменты, и расчёты будут точными 😉
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Вначале округлила значение duration в общем датафрейме, далее в группировку добавила не только группировку по user_id, но и user_id и month. Кроме того, чтобы было удобнее считать добавила в агрегированный датафрейм данные со столбцов start_ride_price, minute_price, rounded_duration. Для start_ride_price, minute_price использовала метод first, который берет первое значение при группировке по user_id, а так как у одного пользователя может быть только один из видов подписки. Исправила формулу подсчета помесячной выручки. Рассчитала формулу в агркгированном датафрейме, исправила подсчет количества поездок с помощью count().
# </div>

# %% [markdown]
# ## Шаг 6. Проверка гипотез

# %%
#6.1
subscribers_duration = common_data[common_data['subscription_type'] == 'ultra']['duration']
print(f'среднее время для пользователей с подпиской: {np.mean(subscribers_duration)}')
# Out:
# среднее время для пользователей с подпиской: 19.221745350500715

# %%
non_subscribers_duration = common_data[common_data['subscription_type'] == 'free']['duration']
print(f'среднее время для пользователей без подписки: {np.mean(non_subscribers_duration)}')
# Out:
# среднее время для пользователей без подписки: 17.535329341317365

# %%
alpha = 0.05
results = st.ttest_ind(subscribers_duration, non_subscribers_duration, alternative='greater')
print('p-значение: ', results.pvalue)
if results.pvalue < alpha:
    print('Отвегаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение:  4.3217800764884575e-08
# Отвегаем нулевую гипотезу

# %% [markdown]
# В нашем случае нулевая гипотеза звучала так: пользователи с подпиской тратят столько же времени, как и пользователи без подписки. Альтернативная: пользователи с подпиской тратят больше времени, чем пользователи без подписки. T-тест показал, что разница действительно существует, а значит пользователи с подпиской тратят больше времени.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
#     Все верно, но мы уже создали два отдельных датафрейма с подпиской и без, можно было использовать их
# </div>

# %%
#6.1
subscribers_distance = common_data[common_data['subscription_type'] == 'ultra']['distance']
print(f'среднее расстояние для пользователей с подпиской: {subscribers_distance.mean()}')
# Out:
# среднее расстояние для пользователей с подпиской: 3129.99988184446

# %%
value = 3130
alpha = 0.05
result = st.ttest_1samp(subscribers_distance, value, alternative='greater')
print('p-значение: ', result.pvalue)
if result.pvalue < alpha:
    print('Отвегаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение:  0.5000014385054872
# Не отвергаем нулевую гипотезу

# %% [markdown]
# Здесь нулевая гипотеза следующая: среднее расстояние, которое проезжают пользователи с подпиской за одну поездку равна 3130 метров. Альтернативная гипотеза: среднее расстояние, которое проезжают пользователи с подпиской за одну поездку больше оптимального. T-тест показал, что нулевая гипотеза не отвергнута, значит среднее расстояние, которое проезжают пользователи с подпиской за одну поездку не превышает 3130 метров, оптимального расстояния.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального" и соответственно в статистическом тесте использовать параметр `alternative = 'greater'`
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Исправила формулировку нулевой гипотезы, в в статистическом тесте изменила параметр на alternative = 'greater'
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
#6.3
subscribers_revenue = monthly_data[monthly_data['subscription_fee'] != 0]['revenue']
non_subscribers_revenue = monthly_data[monthly_data['subscription_fee'] == 0]['revenue']
print(f'средняя помесячная выручка для пользователей с подпиской: {subscribers_revenue.mean()}')
print(f'средняя помесячная выручка для пользователей без подписки: {non_subscribers_revenue.mean()}')
# Out:
# средняя помесячная выручка для пользователей с подпиской: 314.3304721030043
# средняя помесячная выручка для пользователей без подписки: 190.28263473053892

# %% [markdown]
# Нам известно, что пользователи без подписки не платят за нее, это значит, что subscription_fee = 0, а у пользователей с подпиской это значение отлично от 0.

# %%
alpha = 0.05
res = st.ttest_ind(subscribers_revenue, non_subscribers_revenue, alternative='greater')
print('p-значение: ', res.pvalue)
if res.pvalue < alpha:
    print('Отвегаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
# Out:
# p-значение:  0.0
# Отвегаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Результат верный, но много лишних действий. Вся необходимая информация у нас должна получиться в датафрейме с помесячной выручкой и использовать надо именно этот датафрейм без потворных агрегаций и объединений.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Использовала информацию только из датафрейма с помесячной выручкой.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# Нулевая гипотеза: помесячная выручка от пользователей с подпиской равна помесячной выручке для пользователей без подписки. Альтернативная: помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки. T-test отвергнул нулевую гипотезу, значит действительно помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки

# %% [markdown]
# №6.4
# В этом случае нам бы понадобился тест scipy.st.ttest_rel. Этот тест используется если имеются 2 зависимые выборки и проверяется гипотеза о равенстве среднего значения генеральной совокупности до и после изменений. В этом случае лучше использовать одностороннюю(левосторонюю, alternative = 'less') гипотезу, тк мы будем проверять снизилось ли количество обращений в техподдержку. Нулевая гипотеза: после обновления серверов количество обращений не изменилось. Альтернативная гипотеза: после обновления серверов количество обращений снизилось.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Вопрос: какую гипотезу мы будем проверять - одностороннюю или двустороннюю и какие гипотезы мы можем сформулировать?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавила уточнения.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Совершенно верно
# </div>

# %% [markdown]
# #### Шаг 7. Распределения

# %%
n = 100
p = 0.1
distr = pd.Series()
# Out:
# /tmp/ipykernel_182/3397643903.py:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   distr = pd.Series()

# %% [markdown]
# **Общие выводы:**

# %% [markdown]
# ***1. Предобработка данных***

# %% [markdown]
# На данном этапе мы привели столбец date к типу даты pandas. Далее создали новый столбец с номером месяца на основе столбца date. Проверили наличие пропущенных значений и дубликатов в датафреймах.

# %% [markdown]
# ***2. Исследовательский анализ данных***

# %% [markdown]
# На этом шаге мы визуализировали и описывали данные по следующим критериям:
#
# - частота встречаемости городов:
# Здесь мы выяснили, что наиболее встречаемые города это - Пятигорск, Екатиринбург и Ростов-на-Дону. Наименее встречаемый город - Москва.
#
# - соотношение пользователей с подпиской и без подписки:
# Исходя из данных выяснили, что пользователей без подписки больше.
#
# - возраст пользователей:
# Про возраст известно следующее: средний возраст близок к медиане и составляет примерно 25 лет. Максимальный возраст - 43, минимальный - 12 лет.
#
# - расстояние, которое пользователь преодолел за одну поездку:
# Выяснили, что медиана незначительно отличается от среденего значения, что может указывать на нераномерное распределение значений, либо на наличие выбросов, на графике их достаточно много. Максимальная дистанция составляет примерно 7211, минимальная близится к 1.
#
#
# - продолжительность поездок:
# Выяснили, что среднее значение и медиана очень близки, что может говорить об узком диапозоне значений и симметричном распределении. Наличие выбросов наблюдается преимущественно за максимальным значением, есть 1 выброс меньше минимального значения. Максимальная продолжительность поездки составляет примерно 41, минимальная - 0.5.

# %% [markdown]
# ***3. Объединение данных***

# %% [markdown]
# 1) На данном этапе мы объединили данные о пользователях, поездках и подписках в один датафрейм.
# 2) Создали ещё два датафрейма из датафрейма:
# - c данными о пользователях без подписки;
# - с данными о пользователях с подпиской.
# 3) Визуализировали информацию о расстоянии и времени поездок для пользователей обеих категорий.
#
#
#
# - Исследование расстояний для обеих категорий
#
# Сравнив данные обеих категорий, видим, что есть различия. Так пользователи чаще всего используют самокаты без подписки. Среднее расстояние с подпиской больше, чем без подписки. Медиана с подпиской незначительно выше. Минимальное расстояние для пользователей с подпиской значительно больше, чем для пользователей без подписки. Однако максимальное значение для пользователей с подпиской значительно меньше, чем для пользователей без подписки. Это говорит о том, что пользователи без подписки чаще ездят на более далекие расстояния, чем пользователи с подпиской
#
# - Исследование продолжительности для обеих категорий
#
# Сравнив данные для двух групп, можно заметить некие различия. Минимальная длительность поездки для пользователей без подписки меньше, чем для пользователей с подпиской. Максимальная длительность также меньше для пользователей без подписки. Среденее значение больше у пользователей с подпиской, медиана также больше у пользователей с подпиской, что говорит о том, что пользователи с подпиской брали самокат на более длительное время, чем пользователи без подписки.

# %% [markdown]
# ***4. Подсчёт выручки***

# %% [markdown]
# Создали датафрейм с агрегированными данными о поездках и посчитали помесячную выручку, которую принёс каждый пользователь.

# %% [markdown]
# ***5. Проверка гипотез***

# %% [markdown]
# Здесь мы проверяли следующие гипотезы:
#
# - тратят ли пользователи с подпиской больше времени на поездки?
# Здесь T-тест показал, что разница действительно существует, а значит пользователи с подпиской тратят больше времени.
#
# - можно ли сказать, что среднее расстояние, которое проезжают пользователи с подпиской за одну поездку, не превышает 3130 метров?
# В данном случае  T-тест показал, что нулевая гипотеза отвергнута, значит среднее расстояние, которое проезжают пользователи с подпиской за одну поездку не превышает 3130 метров.
#
# - будет ли помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки?
# Здесь T-test отвергнул нулевую гипотезу, значит действительно помесячная выручка от пользователей с подпиской по месяцам выше, чем выручка от пользователей без подписки

# %% [markdown]
# ***6. Возможные рекомендации***
#
# - Анализ эффективности подписок: мы выявили, что средняя помесячная выручка для пользователей с подпиской: 314.3304721030043, а средняя помесячная выручка для пользователей без подписки: 190.28263473053892, а также, что пользователи с подпиской брали самокат на более длительное время, чем пользователи без подписки. это указвает на то, что пользователи с подпиской Ultra тратят больше времени на поездки и приносят больше выручки, стоит сосредоточиться на продвижении именно этого типа подписки.
#
#
# - Целевая реклама: мы выяснили, что средний возраст составляет 25 лет, следовательно, чтобы привлечь пользователей к подписке можно запустить рекламные акции, ориентированные на молодежную аудиторию. Рекламные кампании могут быть направлены на города с высоким уровнем использования сервиса, чтобы увеличить количество подписчиков в этих регионах.
#
#
# - Промо-акции и скидки: Стоит рассмотрить возможность временных акций, предлагающих скидки на первую подписку Ultra или бесплатный пробный период. Это может помочь привлечь новых пользователей и повысить интерес к подписке. Можно также предложить скидки для пользователей, которые переходят с Free на Ultra, чтобы стимулировать их к подписке.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:
#
# * [Как строить красивые графики на Python с Seaborn](https://habr.com/ru/companies/otus/articles/540526/)
#
# * [Seaborn для визуализации данных в Python](https://pythonru.com/biblioteki/seaborn-plot)
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Также мы можем дать рекомендации рекламному отделу, какой вид подписки стоит продвигать.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавила рекомендации.
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Мария, хорошая работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последовательна и вдумчива. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Хорошо, спасибо!
# </div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
# Мария, я готов принять твой проект и если у тебя не осталось каких-либо вопросов, то пришли свой проект на повторное ревью и он будет принят 😊

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Все поняла, спасибо!
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.3</b>
#
# 👋
#
# Мария, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
